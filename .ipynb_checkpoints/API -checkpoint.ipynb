# %%
#bibliothèque de base

import requests
import spacy
import fr_core_news_sm
import numpy as np
import pandas as pd
import re
import nltk
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_files
import tensorflow
from tensorflow import keras

#bibliothèque pour le traitement de texte
from nltk.stem import PorterStemmer 
nltk.download('punkt')
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords
nlp = spacy.load("fr_core_news_sm")

#bibliothèque pour la classification 
from scipy import linalg # SVD
from sklearn import decomposition # NMF
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

from io import StringIO
# Out:
# [nltk_data] Downloading package punkt to /Users/manon/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.4.1-cp38-cp38-macosx_10_11_x86_64.whl (173.9 MB)
#      |████████████████████████████████| 173.9 MB 3.0 MB/s eta 0:00:012  |▍                               | 2.4 MB 3.5 MB/s eta 0:00:49     |██▎                             | 12.6 MB 8.7 MB/s eta 0:00:19     |████                            | 21.4 MB 9.9 MB/s eta 0:00:16     |████▏                           | 22.5 MB 9.9 MB/s eta 0:00:16     |██████████▏                     | 55.0 MB 19.5 MB/s eta 0:00:07     |██████████████                  | 75.7 MB 7.3 MB/s eta 0:00:14     |████████████████▏               | 87.7 MB 9.9 MB/s eta 0:00:09█████████████▏             | 98.6 MB 18.1 MB/s eta 0:00:05     |██████████████████▏             | 98.9 MB 18.1 MB/s eta 0:00:05     |██████████████████████████▍     | 143.3 MB 14.5 MB/s eta 0:00:03
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied: typing-extensions~=3.7.4 in /Users/manon/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.7.4.3)
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 8.5 MB/s  eta 0:00:01
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: h5py~=2.10.0 in /Users/manon/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.14.0-cp38-cp38-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 5.4 MB/s eta 0:00:01
# Requirement already satisfied: wheel~=0.35 in /Users/manon/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.35.1)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 4.6 MB/s eta 0:00:011
# Requirement already satisfied: six~=1.15.0 in /Users/manon/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp38-cp38-macosx_10_9_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 4.8 MB/s eta 0:00:01
# Collecting absl-py~=0.10
#   Downloading absl_py-0.11.0-py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 3.5 MB/s eta 0:00:01
# Collecting tensorboard~=2.4
#   Downloading tensorboard-2.4.1-py3-none-any.whl (10.6 MB)
#      |████████████████████████████████| 10.6 MB 713 kB/s eta 0:00:01
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 3.1 MB/s eta 0:00:01
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Requirement already satisfied: numpy~=1.19.2 in /Users/manon/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.19.2)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 3.8 MB/s  eta 0:00:01
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/manon/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/manon/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (50.3.1.post20201107)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/manon/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (2.24.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.2-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 14.3 MB/s eta 0:00:01
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.25.0-py2.py3-none-any.whl (116 kB)
#      |████████████████████████████████| 116 kB 10.3 MB/s eta 0:00:01
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/manon/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/manon/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/manon/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/manon/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.10)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.7-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 8.8 MB/s eta 0:00:01
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.1-py3-none-any.whl (12 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pyasn1>=0.1.3
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 3.8 MB/s eta 0:00:01
# Building wheels for collected packages: termcolor, wrapt
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=eca57d7dbdb35a114d0d9e901ee3fe5eda109897ba30f4b2f3fc1ef6231a4579
#   Stored in directory: /Users/manon/Library/Caches/pip/wheels/a0/16/9c/5473df82468f958445479c59e784896fa24f4a5fc024b0f501
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp38-cp38-macosx_10_9_x86_64.whl size=32725 sha256=56d673bf6279022c4dd58054a7c4cf871c9464bab44a5f33f44a6d9d9dd57427
#   Stored in directory: /Users/manon/Library/Caches/pip/wheels/5f/fd/9e/b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
# Successfully built termcolor wrapt
# Installing collected packages: flatbuffers, termcolor, opt-einsum, gast, protobuf, google-pasta, grpcio, absl-py, pyasn1, rsa, pyasn1-modules, cachetools, google-auth, oauthlib, requests-oauthlib, google-auth-oauthlib, tensorboard-plugin-wit, markdown, tensorboard, tensorflow-estimator, wrapt, astunparse, keras-preprocessing, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.11.2
#     Uninstalling wrapt-1.11.2:
#       Successfully uninstalled wrapt-1.11.2
# Successfully installed absl-py-0.11.0 astunparse-1.6.3 cachetools-4.2.1 flatbuffers-1.12 gast-0.3.3 google-auth-1.25.0 google-auth-oauthlib-0.4.2 google-pasta-0.2.0 grpcio-1.32.0 keras-preprocessing-1.1.2 markdown-3.3.3 oauthlib-3.1.0 opt-einsum-3.3.0 protobuf-3.14.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.7 tensorboard-2.4.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.4.1 tensorflow-estimator-2.4.0 termcolor-1.1.0 wrapt-1.12.1

# %% [markdown]
# ## chargement des données

# %%
df = pd.read_excel('./cr.xlsx')

# %%
df.shape
# Out:
# (5265, 3)

# %%
df.category.unique()
# Out:
# array(['Assurance_de_Biens', 'Assurance_de_Personnes',
#        'BAQ_Services_Bancaires', 'Bilan_suivi_relationnel',
#        'Credit_agri_pro', 'Credit_conso', 'Credit_habitat',
#        'Credit_travaux', 'Credit_vehicule',
#        'Entree_en_relation_Conquetes', 'Epargne_disponible',
#        'Epargne_terme', 'Evenements_de_vie',
#        'Non_specifie_Credit_Assurance_Epargne_',
#        'Point_d_attention_risques', 'Projet_exceptionnel_',
#        'Reclamation_Insatisfaction_client'], dtype=object)

# %%
df.columns
# Out:
# Index(['text', 'content', 'category'], dtype='object')

# %% [markdown]
# ## Modification du tableau

# %%
# je prends que les colonnes qui m'interresse
col = ['category', 'text', 'content']
df = df[col]
df = df[pd.notnull(df['text'])]

df.columns = ['category', 'text', 'content']

# je factorise et crée des dictionnaires pour liér la catégorie à son id 
df['category_id'] = df['category'].factorize()[0]

category_id_df = df[['category', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'category']].values)

content_id_df = df[['category', 'content']].drop_duplicates().sort_values('content')
content_to_id = dict(content_id_df.values)

df.head()
# Out:
#              category                                               text  \
# 0  Assurance_de_Biens  entretien avec Monsieur \n\n proposition d'ass...
# 1  Assurance_de_Biens  entretien avec Monsieur \n\n proposition d'ass...
# 2  Assurance_de_Biens  cliente cliente reçu le 8 octobre   pour renég...
# 3  Assurance_de_Biens   rendez-vous pour connaissance /  mariée 3 enf...
# 4  Assurance_de_Biens  Cliente étudiante en BTS. Fin étude juin 2020....
#
#                 content  category_id
# 0        assurance auto            0
# 1        assurance auto            0
# 2  assurance automobile            0
# 3                  IARD            0
# 4                    NH            0

# %% [markdown]
# ## data preprocessing

# %%
# Chargement stopwords français
stop_words = stopwords.words('french')
    
#Initialize stemmer, which will take words and convert words to their "stem," e.g. Playing-> Play
ps = PorterStemmer() 

# Enlever les charactères nons alphabétiques, espaces et convertir toutes les lettres en minuscules
# References: https://www.analyticsvidhya.com/blog/2019/04/predicting-movie-genres-nlp-multi-label-classification/
def clean_text(txt): 
    txt= txt.lower()   #lowercase
    txt= re.sub("[^a-zA-Z]"," ",txt) #Remove everything except alphabetical characters 
    txt= word_tokenize(txt) #tokenize (split into list and remove whitespace)
    
    #initialize list to store clean text
    clean_text=""
      
    #iterate over each word
    for w in txt:      
        #remove stopwords
        if w not in stop_words:
            #stem=ps.stem(w) #stem 
            stem=w
            clean_text += stem +" " 
    return clean_text


text_new=[] #declare a list to hold new movies

for cell in df['text']:    
    txt= clean_text(cell)
    text_new.append(txt)
    
#add new info column to the dataframe
df['text'] = text_new 
df.head(5)
# Out:
#              category                                               text  \
# 0  Assurance_de_Biens  entretien monsieur proposition assurance auto ...
# 1  Assurance_de_Biens  entretien monsieur proposition assurance auto ...
# 2  Assurance_de_Biens  cliente cliente re u octobre ren gociation cr ...
# 3  Assurance_de_Biens  rendez connaissance mari e enfants petits enfa...
# 4  Assurance_de_Biens  cliente tudiante bts fin tude juin a recontact...
#
#                 content  category_id
# 0        assurance auto            0
# 1        assurance auto            0
# 2  assurance automobile            0
# 3                  IARD            0
# 4                    NH            0

# %% [markdown]
# ## n-grams des catégories

# %%
final_stopwords_list = stopwords.words('english') + stopwords.words('french')

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='utf-8', ngram_range=(1, 2), stop_words=final_stopwords_list)
features = tfidf.fit_transform(df.text).toarray()
labels = df.category_id

features.shape
# Out:
# (5265, 18532)

# %% [markdown]
# ## corrélation entre le thème et les mots

# %%
N = 3
for category, category_id, in sorted(category_to_id.items()):
    features_chi2 = chi2(features, labels == category_id)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    print("# '{}':".format(category))
    print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
    print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
# Out:
# # 'Assurance_de_Biens':
#   . Most correlated unigrams:
# . habitation
# . devis
# . nh
#   . Most correlated bigrams:
# . assurance actuellement
# . assurance nh
# . contrat nh
# # 'Assurance_de_Personnes':
#   . Most correlated unigrams:
# . adrea
# . aav
# . mutuelle
#   . Most correlated bigrams:
# . voir contrat
# . propo garantie
# . chez adrea
# # 'BAQ_Services_Bancaires':
#   . Most correlated unigrams:
# . commande
# . cac
# . carte
#   . Most correlated bigrams:
# . nouvelle cb
# . carte mozaic
# . ch quier
# # 'Bilan_suivi_relationnel':
#   . Most correlated unigrams:
# . bilan
# . mesures
# . courtoisie
#   . Most correlated bigrams:
# . appel courtoisie
# . prendre nouvelles
# . fixer rendez
# # 'Credit_agri_pro':
#   . Most correlated unigrams:
# . bail
# . cabinet
# . pge
#   . Most correlated bigrams:
# . report mois
# . demande pge
# . dit bail
# # 'Credit_conso':
#   . Most correlated unigrams:
# . rmd
# . suppletis
# . conso
#   . Most correlated bigrams:
# . dit conso
# . va rembourser
# . pr tudiant
# # 'Credit_habitat':
#   . Most correlated unigrams:
# . locatif
# . habitat
# . projet
#   . Most correlated bigrams:
# . habitat cours
# . rachat soulte
# . calcul enveloppe
# # 'Credit_travaux':
#   . Most correlated unigrams:
# . parties
# . confort
# . travaux
#   . Most correlated bigrams:
# . confort travaux
# . pac confort
# . pr travaux
# # 'Credit_vehicule':
#   . Most correlated unigrams:
# . bon
# . hicule
# . auto
#   . Most correlated bigrams:
# . auto mois
# . bon commande
# . pr auto
# # 'Entree_en_relation_Conquetes':
#   . Most correlated unigrams:
# . fils
# . enfants
# . fille
#   . Most correlated bigrams:
# . transfert pargne
# . mineur ouverture
# . ouverture compte
# # 'Epargne_disponible':
#   . Most correlated unigrams:
# . lep
# . csl
# . livret
#   . Most correlated bigrams:
# . livret pargne
# . pargne populaire
# . ouverture livret
# # 'Epargne_terme':
#   . Most correlated unigrams:
# . vie
# . floriane
# . per
#   . Most correlated bigrams:
# . per assurance
# . plan pargne
# . assurance vie
# # 'Evenements_de_vie':
#   . Most correlated unigrams:
# . annonce
# . licenciement
# . majorit
#   . Most correlated bigrams:
# . mois juillet
# . passage majorit
# . vu mois
# # 'Non_specifie_Credit_Assurance_Epargne_':
#   . Most correlated unigrams:
# . moiti
# . assurances
# . copies
#   . Most correlated bigrams:
# . tr bien
# . rendez assurances
# . fait financement
# # 'Point_d_attention_risques':
#   . Most correlated unigrams:
# . refus
# . retard
# . pause
#   . Most correlated bigrams:
# . dossier surendettement
# . pause mensualit
# . pause mois
# # 'Projet_exceptionnel_':
#   . Most correlated unigrams:
# . ritage
# . donation
# . succession
#   . Most correlated bigrams:
# . investissement immobilier
# . suite succession
# . succession maman
# # 'Reclamation_Insatisfaction_client':
#   . Most correlated unigrams:
# . commission
# . initi
# . clamation
#   . Most correlated bigrams:
# . client contact
# . sauver relation
# . envoy cliente

# %%
model.fit(features, labels)
N = 2
for Product, category_id in sorted(category_to_id.items()):
  indices = np.argsort(model.coef_[category_id])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 1][:N]
  bigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 2][:N]
  print("# '{}':".format(Product))
  print("  . Top unigrams:\n       . {}".format('\n       . '.join(unigrams)))
  print("  . Top bigrams:\n       . {}".format('\n       . '.join(bigrams)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-73761122d3d1> in <module>
# ----> 1 model.fit(features, labels)
#       2 N = 2
#       3 for Product, category_id in sorted(category_to_id.items()):
#       4   indices = np.argsort(model.coef_[category_id])
#       5   feature_names = np.array(tfidf.get_feature_names())[indices]
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## train test

# %%
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['category'], random_state = 0)

count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %% [markdown]
# # modèle

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn import svm
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# ignore ConvergenceWarnings
from  warnings import simplefilter
from sklearn.exceptions import ConvergenceWarning
simplefilter("ignore", category=ConvergenceWarning)

models = [
    { "estimater": SGDClassifier(),
      "params": {
          "loss": ['hinge','log','perceptron'], 
          "penalty": ['l2', 'l1'], 
          "alpha": [ 0.0003],
          "early_stopping": [True],
          "max_iter": [1000],
          "random_state": [42]
      }
     }
]

# %%
import pickle

# %%
clf = LinearSVC()

X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)

s = pickle.dumps(model)
model2 = pickle.loads(s)
model2.predict(X_test)
# Out:
# array([10,  1, 14, ...,  2,  2,  9])

# %%
from joblib import dump, load
dump(model, 'filename.joblib')
# Out:
# ['filename.joblib']

# %%
model = load('filename.joblib')

# %%
print(model)
# Out:
# LinearSVC()

# %% [markdown]
# # evaluation du modèle

# %% [markdown]
# ## heatmap

# %%
model = LinearSVC()
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.category.values, yticklabels=category_id_df.category.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# ## tableau des métrics

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, y_pred, target_names=df['category'].unique()))
# Out:
#                                         precision    recall  f1-score   support
#
#                     Assurance_de_Biens       0.24      0.26      0.25       128
#                 Assurance_de_Personnes       0.20      0.16      0.18       132
#                 BAQ_Services_Bancaires       0.27      0.38      0.31       121
#                Bilan_suivi_relationnel       0.20      0.13      0.16       121
#                        Credit_agri_pro       0.41      0.39      0.40        23
#                           Credit_conso       0.22      0.24      0.23        41
#                         Credit_habitat       0.35      0.41      0.38       133
#                         Credit_travaux       0.20      0.20      0.20        15
#                        Credit_vehicule       0.25      0.20      0.22        30
#           Entree_en_relation_Conquetes       0.22      0.26      0.24       161
#                     Epargne_disponible       0.29      0.34      0.31       116
#                          Epargne_terme       0.37      0.47      0.41       259
#                      Evenements_de_vie       0.12      0.04      0.06        47
# Non_specifie_Credit_Assurance_Epargne_       0.08      0.05      0.06       120
#              Point_d_attention_risques       0.34      0.34      0.34       200
#                   Projet_exceptionnel_       0.21      0.07      0.11        41
#      Reclamation_Insatisfaction_client       0.25      0.08      0.12        50
#
#                               accuracy                           0.28      1738
#                              macro avg       0.25      0.24      0.23      1738
#                           weighted avg       0.26      0.28      0.26      1738

# %% [markdown]
# ## affichage des erreurs

# %%
from IPython.display import display

for predicted in category_id_df.category_id:
    for actual in category_id_df.category_id:
        if predicted != actual and conf_mat[actual, predicted] >= 5:
            print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], id_to_category[predicted], conf_mat[actual, predicted]))
            display(df.loc[indices_test[(y_test == actual) & (y_pred == predicted)]][['category', 'text']])
    print('')
# Out:
# 'Assurance_de_Personnes' predicted as 'Assurance_de_Biens' : 20 examples.
#                    category                                               text
# 660  Assurance_de_Personnes  suite a appel courtoisie mle travail enfants m...
# 539  Assurance_de_Personnes  pose contrat souhaite pj moment nh offre inter...
# 444  Assurance_de_Personnes  envoi docs ouverture vers avenir elyana livret...
# 535  Assurance_de_Personnes  marie sous paration enfants charge ans rachat ...
# 661  Assurance_de_Personnes  suite a appel courtoisie mle travail enfants m...
# 731  Assurance_de_Personnes  vu entretien r am nagement pr eme donc frais g...
# 559  Assurance_de_Personnes  appel phonique sortant jour proposition garant...
# 735  Assurance_de_Personnes  monsieur pastor vu janvier rapport fonctionnem...
# 666  Assurance_de_Personnes  bilan fait mme couple a conduit principalement...
# 572  Assurance_de_Personnes  rendez phonique jour o mademoiselle solidit fa...
# 528  Assurance_de_Personnes  compte mme mr retraite flux placements autres ...
# 420  Assurance_de_Personnes                                     devis atm gav
# 558  Assurance_de_Personnes  appel phonique sortant jour proposition garant...
# 565  Assurance_de_Personnes  rdv r alis jour bilan iard r cup ration contra...
# 415  Assurance_de_Personnes  propo lep va r fl chir proposition devis nh a ...
# 619  Assurance_de_Personnes  conducteur tramway valencienne gdc compl menta...
# 729  Assurance_de_Personnes  donation parents monsieur montant mise place d...
# 545  Assurance_de_Personnes  mise place nouveau contrat assurance habitatio...
# 555  Assurance_de_Personnes  proposition nh plus protection juridique devis...
# 620  Assurance_de_Personnes  conducteur tramway valencienne gdc compl menta...
# 'BAQ_Services_Bancaires' predicted as 'Assurance_de_Biens' : 11 examples.
#                     category  \
# 862   BAQ_Services_Bancaires
# 854   BAQ_Services_Bancaires
# 861   BAQ_Services_Bancaires
# 918   BAQ_Services_Bancaires
# 1116  BAQ_Services_Bancaires
# 976   BAQ_Services_Bancaires
# 831   BAQ_Services_Bancaires
# 844   BAQ_Services_Bancaires
# 803   BAQ_Services_Bancaires
# 1077  BAQ_Services_Bancaires
# 1127  BAQ_Services_Bancaires
#
#                                                    text
# 862   architecte auto entrepreneur libataire locatai...
# 854   client pars voyage prochainement application o...
# 861   architecte auto entrepreneur libataire locatai...
# 918   madame enseignante actuellement mise dispositi...
# 1116  per oit partie retraite depuis janvier mois ca...
# 976   transformation compte joint compte individuel ...
# 831   entretien monsieur madame mobilit bancaire ent...
# 844   rendez cr dit important suite vente maison pap...
# 803   marie communaut enfants dont fils a repris ent...
# 1077  mise place cac budget prot ger ration moyens p...
# 1127  monsieur pastor vu janvier rapport fonctionnem...
# 'Bilan_suivi_relationnel' predicted as 'Assurance_de_Biens' : 13 examples.
#                      category  \
# 1299  Bilan_suivi_relationnel
# 1224  Bilan_suivi_relationnel
# 1457  Bilan_suivi_relationnel
# 1509  Bilan_suivi_relationnel
# 1246  Bilan_suivi_relationnel
# 1461  Bilan_suivi_relationnel
# 1216  Bilan_suivi_relationnel
# 1386  Bilan_suivi_relationnel
# 1275  Bilan_suivi_relationnel
# 1240  Bilan_suivi_relationnel
# 1428  Bilan_suivi_relationnel
# 1366  Bilan_suivi_relationnel
# 1380  Bilan_suivi_relationnel
#
#                                                    text
# 1299  rdv r alis jour bilan iard r cup ration contra...
# 1224  rendez cr dit important suite vente maison pap...
# 1457  bilan phonique iard concernant a monsieur mada...
# 1509  bilan global assurance propri taire r sidence ...
# 1246  anciens commer ants sup rette belbex contentem...
# 1461  compte associ gestion bien locatif mensualit p...
# 1216  change client suite demande geste commercial c...
# 1386  bilan fait mme couple a conduit principalement...
# 1275  compte mme mr retraite flux placements autres ...
# 1240  architecte auto entrepreneur libataire locatai...
# 1428  re u cleinte faire bilan assurance a fils dont...
# 1366  client axaaxa assurance minelea r alis voiture...
# 1380  suite a appel courtoisie mle travail enfants m...
# 'Entree_en_relation_Conquetes' predicted as 'Assurance_de_Biens' : 8 examples.
#                           category  \
# 2325  Entree_en_relation_Conquetes
# 2421  Entree_en_relation_Conquetes
# 2644  Entree_en_relation_Conquetes
# 2708  Entree_en_relation_Conquetes
# 2357  Entree_en_relation_Conquetes
# 2355  Entree_en_relation_Conquetes
# 2324  Entree_en_relation_Conquetes
# 2358  Entree_en_relation_Conquetes
#
#                                                    text
# 2325  marie communaut enfants dont fils a repris ent...
# 2421  a re u client jour suite demande rendez planif...
# 2644    compagnie fils unique laurent h sit prendre pj
# 2708  monsieur pastor vu janvier rapport fonctionnem...
# 2357  entretien monsieur madame mobilit bancaire ent...
# 2355  contact client janvier suite motif contact cr ...
# 2324  marie communaut enfants dont fils a repris ent...
# 2358  entretien monsieur madame mobilit bancaire ent...
# 'Epargne_terme' predicted as 'Assurance_de_Biens' : 8 examples.
#            category                                               text
# 3536  Epargne_terme  transformation compte joint compte individuel ...
# 3535  Epargne_terme  rdv tel jour madame souhaite conseils rachat a...
# 3171  Epargne_terme  bloquer vers avenir vu aussi reviendra compte ...
# 3226  Epargne_terme  suite rdv but r am nager pr propo per car clie...
# 3537  Epargne_terme  transformation compte joint compte individuel ...
# 3822  Epargne_terme  souscription jour part sociale nh protection j...
# 3172  Epargne_terme  echu sonance vie p mme voulait profiter retire...
# 3861  Epargne_terme  donation parents monsieur montant mise place d...
# 'Non_specifie_Credit_Assurance_Epargne_' predicted as 'Assurance_de_Biens' : 11 examples.
#                                     category  \
# 4330  Non_specifie_Credit_Assurance_Epargne_
# 4404  Non_specifie_Credit_Assurance_Epargne_
# 4183  Non_specifie_Credit_Assurance_Epargne_
# 4067  Non_specifie_Credit_Assurance_Epargne_
# 4081  Non_specifie_Credit_Assurance_Epargne_
# 4170  Non_specifie_Credit_Assurance_Epargne_
# 4068  Non_specifie_Credit_Assurance_Epargne_
# 4296  Non_specifie_Credit_Assurance_Epargne_
# 4152  Non_specifie_Credit_Assurance_Epargne_
# 4105  Non_specifie_Credit_Assurance_Epargne_
# 4234  Non_specifie_Credit_Assurance_Epargne_
#
#                                                    text
# 4330  monsieur pastor vu janvier rapport fonctionnem...
# 4404  bilan assurance fait jour madame assur e chez ...
# 4183  rdv r alis jour bilan iard r cup ration contra...
# 4067  rencontr madame aujourd hui vu ensemble donc m...
# 4081  entretien monsieur madame mobilit bancaire ent...
# 4170  plus proposer assurance assurer potassium pers...
# 4068  vente r sidence principale juillet acquisition...
# 4296  souscription jour part sociale nh protection j...
# 4152  client relancer jour assurer bien financ revoi...
# 4105  devis x nh maison re non occup e relance devis...
# 4234  client axaaxa assurance minelea r alis voiture...
# 'Point_d_attention_risques' predicted as 'Assurance_de_Biens' : 14 examples.
#                        category  \
# 4636  Point_d_attention_risques
# 4824  Point_d_attention_risques
# 4857  Point_d_attention_risques
# 4707  Point_d_attention_risques
# 4488  Point_d_attention_risques
# 4448  Point_d_attention_risques
# 4831  Point_d_attention_risques
# 4830  Point_d_attention_risques
# 4656  Point_d_attention_risques
# 4454  Point_d_attention_risques
# 4706  Point_d_attention_risques
# 4657  Point_d_attention_risques
# 4453  Point_d_attention_risques
# 4821  Point_d_attention_risques
#
#                                                    text
# 4636  compte mme mr retraite flux placements autres ...
# 4824  bilan fait mme couple a conduit principalement...
# 4857  mise place cac budget prot ger ration moyens p...
# 4707  mr tait content appel a refus proposition devi...
# 4488  cliente phone car souhaite r silier contrat mu...
# 4448  client assur deux roues chez assu assur e v hi...
# 4831  proposition refus e client souhaite garder aut...
# 4830  proposition refus e client souhaite garder aut...
# 4656  plus proposer assurance assurer potassium pers...
# 4454  echu sonance vie p mme voulait profiter retire...
# 4706  mr tait content appel a refus proposition devi...
# 4657  pose contrat souhaite pj moment nh offre inter...
# 4453  echu sonance vie p mme voulait profiter retire...
# 4821  bilan fait mme couple a conduit principalement...
# 'Assurance_de_Biens' predicted as 'Assurance_de_Personnes' : 22 examples.
#                category                                               text
# 308  Assurance_de_Biens  rdv phonique surendettement cliente a contact ...
# 311  Assurance_de_Biens  fait devis ass nh pj envoy courrier postal pos...
# 142  Assurance_de_Biens  somme dav importante projets particuliers mome...
# 241  Assurance_de_Biens  rdv patrimoine ok re e refus commande carte es...
# 144  Assurance_de_Biens  somme dav importante projets particuliers mome...
# 66   Assurance_de_Biens  depose proposition assurances nh res helio cot...
# 4    Assurance_de_Biens  cliente tudiante bts fin tude juin a recontact...
# 44   Assurance_de_Biens  propos gav vie pro plus garantie transfert mul...
# 137  Assurance_de_Biens  chercheur cnrs cdd ans g ologie travail tecton...
# 378  Assurance_de_Biens  suite change jour souhait pargne livret ok ldd...
# 388  Assurance_de_Biens  mme divorc e ex mari touche retraite reversion...
# 34   Assurance_de_Biens  fait formation bpjeps loisirs tous publics tra...
# 143  Assurance_de_Biens  somme dav importante projets particuliers mome...
# 383  Assurance_de_Biens  mr mme venus rdv r silisation gob chez aviva d...
# 242  Assurance_de_Biens  rdv patrimoine ok re e refus commande carte es...
# 135  Assurance_de_Biens               proposition gobs ass vie bilan iard
# 210  Assurance_de_Biens  suite bilan fait jour sous a nh aav devis comp...
# 122  Assurance_de_Biens  aso besoin particulier client tel printemps pr...
# 401  Assurance_de_Biens  monsieur fleuriste ristourne frais client pr v...
# 325  Assurance_de_Biens              maif mgen mnh rdvs devis cal juillet
# 368  Assurance_de_Biens  augmentation abonnement p r partition euros mo...
# 182  Assurance_de_Biens  clients re u devis mutuelle madame int grale m...
# 'Bilan_suivi_relationnel' predicted as 'Assurance_de_Personnes' : 12 examples.
#                      category  \
# 1529  Bilan_suivi_relationnel
# 1460  Bilan_suivi_relationnel
# 1328  Bilan_suivi_relationnel
# 1431  Bilan_suivi_relationnel
# 1515  Bilan_suivi_relationnel
# 1309  Bilan_suivi_relationnel
# 1427  Bilan_suivi_relationnel
# 1237  Bilan_suivi_relationnel
# 1265  Bilan_suivi_relationnel
# 1470  Bilan_suivi_relationnel
# 1420  Bilan_suivi_relationnel
# 1377  Bilan_suivi_relationnel
#
#                                                    text
# 1529  monsieur fleuriste ristourne frais client pr v...
# 1460  ouverture liv a fille leana vient naitre monte...
# 1328  suite bilan fait jour sous a nh aav devis comp...
# 1431  client assur groupama ancien assur pacifica de...
# 1515  suite change jour souhait pargne livret ok ldd...
# 1309  vu janvier propos reprise pr conso actuellemen...
# 1427  fait devis ass nh pj envoy courrier postal pos...
# 1237  rdv jour cr dit voiture suppl tis contrepartie...
# 1265               proposition gobs ass vie bilan iard
# 1470  vu deux fois rendez a fait devis mutuelle int ...
# 1420  appelle suite engagements pris lors dernier re...
# 1377  compte rendu rendez mars monsieur ducateur sp ...
# 'Entree_en_relation_Conquetes' predicted as 'Assurance_de_Personnes' : 7 examples.
#                           category  \
# 2443  Entree_en_relation_Conquetes
# 2776  Entree_en_relation_Conquetes
# 2396  Entree_en_relation_Conquetes
# 2652  Entree_en_relation_Conquetes
# 2329  Entree_en_relation_Conquetes
# 2778  Entree_en_relation_Conquetes
# 2379  Entree_en_relation_Conquetes
#
#                                                    text
# 2443  client renseigne assurer interm diaire garanti...
# 2776  mme divorc e ex mari touche retraite reversion...
# 2396  rdv jour cr dit voiture suppl tis contrepartie...
# 2652  rdv phonique surendettement cliente a contact ...
# 2329  suite zoo janvier cliente mutuelle conjoint cd...
# 2778  mme divorc e ex mari touche retraite reversion...
# 2379  depose proposition assurances nh res helio cot...
# 'Epargne_terme' predicted as 'Assurance_de_Personnes' : 5 examples.
#            category                                               text
# 3282  Epargne_terme  remboursement frais revoir cliente debut avril...
# 3342  Epargne_terme  cliente licenci e fin a touch prime deux prime...
# 3845  Epargne_terme  etudiante licence arts plastique paul val ry m...
# 3341  Epargne_terme  cliente licenci e fin a touch prime deux prime...
# 3567  Epargne_terme  rdv mme per ok per faire pr auto sold int gral...
# 'Non_specifie_Credit_Assurance_Epargne_' predicted as 'Assurance_de_Personnes' : 5 examples.
#                                     category  \
# 4331  Non_specifie_Credit_Assurance_Epargne_
# 4063  Non_specifie_Credit_Assurance_Epargne_
# 4323  Non_specifie_Credit_Assurance_Epargne_
# 4202  Non_specifie_Credit_Assurance_Epargne_
# 4310  Non_specifie_Credit_Assurance_Epargne_
#
#                                                    text
# 4331  client ok mettre place abo bien situation pro ...
# 4063  souhait transfert comptes entrants ldd cloture...
# 4323  vu deux fois rendez a fait devis mutuelle int ...
# 4202  cliente groupama allianz assurances veut devis...
# 4310  etudiante licence arts plastique paul val ry m...
# 'Point_d_attention_risques' predicted as 'Assurance_de_Personnes' : 8 examples.
#                        category  \
# 4792  Point_d_attention_risques
# 4772  Point_d_attention_risques
# 4548  Point_d_attention_risques
# 4766  Point_d_attention_risques
# 4948  Point_d_attention_risques
# 4812  Point_d_attention_risques
# 4694  Point_d_attention_risques
# 4644  Point_d_attention_risques
#
#                                                    text
# 4792  souhaitait renegocier pr possibilit tant donn ...
# 4772  rdv patrimoine ok re e refus commande carte es...
# 4548  cliente jour slov nie pendant jusqu juillet cl...
# 4766  renvoi ch acs client re u pacifica contrat peu...
# 4948  augmentation abonnement p r partition euros mo...
# 4812  fais devis mutuelle jour actuellement assur ch...
# 4694  monsieur madame venus voir car diff rend sofin...
# 4644  mme sous mutuelle groupe jusqu clients vivent ...
# 'Reclamation_Insatisfaction_client' predicted as 'Assurance_de_Personnes' : 5 examples.
#                                category  \
# 5120  Reclamation_Insatisfaction_client
# 5218  Reclamation_Insatisfaction_client
# 5217  Reclamation_Insatisfaction_client
# 5254  Reclamation_Insatisfaction_client
# 5194  Reclamation_Insatisfaction_client
#
#                                                    text
# 5120  souhait transfert comptes entrants ldd cloture...
# 5218  prise charge commission invention janvier mail...
# 5217  prise charge commission invention janvier mail...
# 5254  mr mme venus rdv r silisation gob chez aviva d...
# 5194  changement situation retraite entre mois fait ...
# 'Assurance_de_Biens' predicted as 'BAQ_Services_Bancaires' : 11 examples.
#                category                                               text
# 29   Assurance_de_Biens  rdv pris cliente suite r ception sms budget pr...
# 265  Assurance_de_Biens  mail pret attente justifs revenus ir charges e...
# 125  Assurance_de_Biens  prospect nouveau client cacf pr concr tis via ...
# 188  Assurance_de_Biens  rendez jour cliente souhaite rencontrer faire ...
# 117  Assurance_de_Biens  point dossier offre acceptation immo ok signat...
# 170  Assurance_de_Biens  bonjour fait pr immobilier prospect financer r...
# 261  Assurance_de_Biens  suite contact atourisk proposition budget prot...
# 162  Assurance_de_Biens  entretien point prelevements paiements carte m...
# 294  Assurance_de_Biens  suite part coll gue a chassaing reprise dossie...
# 185  Assurance_de_Biens  suite mise place cr dit immobilier achat appar...
# 118  Assurance_de_Biens  mandat mobilit bancaire compte joint sign clie...
# 'Assurance_de_Personnes' predicted as 'BAQ_Services_Bancaires' : 11 examples.
#                    category                                               text
# 534  Assurance_de_Personnes  entretien point prelevements paiements carte m...
# 548  Assurance_de_Personnes  bonjour fait pr immobilier prospect financer r...
# 776  Assurance_de_Personnes  contente suite fraude cb prise charge poste po...
# 584  Assurance_de_Personnes  seul monsieur tait pr sent client venu agence ...
# 649  Assurance_de_Personnes  suite contact atourisk proposition budget prot...
# 538  Assurance_de_Personnes  rdv ouverture second compte ch autre carte pre...
# 775  Assurance_de_Personnes  contente suite fraude cb prise charge poste po...
# 695  Assurance_de_Personnes  madame madame raucoules pass agence chercher c...
# 509  Assurance_de_Personnes  prospect nouveau client cacf pr concr tis via ...
# 622  Assurance_de_Personnes  augmentation couvert revenus madame mont e gam...
# 685  Assurance_de_Personnes  rendez annuel droit compte client souhaite con...
# 'Bilan_suivi_relationnel' predicted as 'BAQ_Services_Bancaires' : 9 examples.
#                      category  \
# 1430  Bilan_suivi_relationnel
# 1343  Bilan_suivi_relationnel
# 1419  Bilan_suivi_relationnel
# 1523  Bilan_suivi_relationnel
# 1367  Bilan_suivi_relationnel
# 1484  Bilan_suivi_relationnel
# 1259  Bilan_suivi_relationnel
# 1391  Bilan_suivi_relationnel
# 1250  Bilan_suivi_relationnel
#
#                                                    text
# 1430  entretien octobre point compte mise place vire...
# 1343  suite meilleur situation financi re point comp...
# 1419  rendez annuel droit compte client souhaite con...
# 1523  envoie formulaire demande changement date pr v...
# 1367  travaille restauration h tel sequoia disney ch...
# 1484  vu client aujourd hui ouverture compte client ...
# 1259  prospect nouveau client cacf pr concr tis via ...
# 1391  suite mail client mars relance phonique jour e...
# 1250  madame souhaitait faire point comptes envisage...
# 'Credit_habitat' predicted as 'BAQ_Services_Bancaires' : 14 examples.
#             category                                               text
# 2049  Credit_habitat  rendez octobre point comptes fonctionnement vi...
# 2027  Credit_habitat  suite part coll gue a chassaing reprise dossie...
# 2036  Credit_habitat  mme souhaite ouvrir compte perso chez car trop...
# 1902  Credit_habitat  bonjour fait pr immobilier prospect financer r...
# 1997  Credit_habitat  dossier locatif fait romain cet interne orl tr...
# 1921  Credit_habitat  suite mise place cr dit immobilier achat appar...
# 1774  Credit_habitat  mise place vu cliente cac commande ch quier cb...
# 2102  Credit_habitat  facilit faire commande carte gold soci taire d...
# 2048  Credit_habitat  rendez octobre point comptes fonctionnement vi...
# 2108  Credit_habitat  re u matin mademoiselle venez faire virement a...
# 2100  Credit_habitat  facilit faire commande carte gold soci taire d...
# 2060  Credit_habitat  cliente pr f rence gestion ca direct pret rp e...
# 1960  Credit_habitat  etude ream non porteuse maintien ech puis redu...
# 1855  Credit_habitat  mandat mobilit bancaire compte joint sign clie...
# 'Entree_en_relation_Conquetes' predicted as 'BAQ_Services_Bancaires' : 11 examples.
#                           category  \
# 2337  Entree_en_relation_Conquetes
# 2315  Entree_en_relation_Conquetes
# 2717  Entree_en_relation_Conquetes
# 2338  Entree_en_relation_Conquetes
# 2481  Entree_en_relation_Conquetes
# 2716  Entree_en_relation_Conquetes
# 2722  Entree_en_relation_Conquetes
# 2568  Entree_en_relation_Conquetes
# 2645  Entree_en_relation_Conquetes
# 2735  Entree_en_relation_Conquetes
# 2399  Entree_en_relation_Conquetes
#
#                                                    text
# 2337  cr dit immobilier r alis convention courtier e...
# 2315  pr sentation offre web edi ibis fait jour poin...
# 2717  client install depuis an demande ren go taux t...
# 2338  cr dit immobilier r alis convention courtier e...
# 2481  bonjour fait pr immobilier prospect financer r...
# 2716  client install depuis an demande ren go taux t...
# 2722  vu client aujourd hui ouverture compte client ...
# 2568  vu cliente regul compte signature lettre ch at...
# 2645  rdv car penses courantes augment derni rement ...
# 2735  rendez suivi suite dition offre pr signer macr...
# 2399  ouverture compte pro souscription offre propul...
# 'Epargne_disponible' predicted as 'BAQ_Services_Bancaires' : 9 examples.
#                 category                                               text
# 2841  Epargne_disponible  rdv jour passage ans commande cb mcd di mise p...
# 2992  Epargne_disponible  vu cliente regul compte signature lettre ch at...
# 3098  Epargne_disponible  rendez suivi suite dition offre pr signer macr...
# 2814  Epargne_disponible  rdv pris cliente suite r ception sms budget pr...
# 3045  Epargne_disponible  entretien octobre point compte mise place vire...
# 2884  Epargne_disponible  propos client changement carte bancaire mozaic...
# 3058  Epargne_disponible  cliente pr f rence gestion ca direct pret rp e...
# 3056  Epargne_disponible  cliente pr f rence gestion ca direct pret rp e...
# 3129  Epargne_disponible  madame a cid ouvrir compte chez afin proc der ...
# 'Epargne_terme' predicted as 'BAQ_Services_Bancaires' : 10 examples.
#            category                                               text
# 3480  Epargne_terme  bonjour fait pr immobilier prospect financer r...
# 3487  Epargne_terme  mise place cac modules dont premium formulaire...
# 3787  Epargne_terme  rdv car penses courantes augment derni rement ...
# 3548  Epargne_terme  seul monsieur tait pr sent client venu agence ...
# 3870  Epargne_terme           pels plafonn avant ans fait prorogeront
# 3733  Epargne_terme  passage majorit penser bien refaire signer com...
# 3255  Epargne_terme  pea madame vente actions ventilation pargne di...
# 3798  Epargne_terme  rendez octobre point comptes fonctionnement vi...
# 3197  Epargne_terme  rdv pris cliente suite r ception sms budget pr...
# 3500  Epargne_terme  suite mise place cr dit immobilier achat appar...
# 'Non_specifie_Credit_Assurance_Epargne_' predicted as 'BAQ_Services_Bancaires' : 10 examples.
#                                     category  \
# 4195  Non_specifie_Credit_Assurance_Epargne_
# 4412  Non_specifie_Credit_Assurance_Epargne_
# 4157  Non_specifie_Credit_Assurance_Epargne_
# 4184  Non_specifie_Credit_Assurance_Epargne_
# 4281  Non_specifie_Credit_Assurance_Epargne_
# 4287  Non_specifie_Credit_Assurance_Epargne_
# 4286  Non_specifie_Credit_Assurance_Epargne_
# 4130  Non_specifie_Credit_Assurance_Epargne_
# 4185  Non_specifie_Credit_Assurance_Epargne_
# 4277  Non_specifie_Credit_Assurance_Epargne_
#
#                                                    text
# 4195  seul monsieur tait pr sent client venu agence ...
# 4412  mr mme compte egalement a caisse ep servent ep...
# 4157  suite communication phonique f vrier monsieur ...
# 4184  rendez jour cliente souhaite rencontrer faire ...
# 4281  cliente chef cabine chez airfrance depuis sala...
# 4287  rendez octobre point comptes fonctionnement vi...
# 4286  rendez octobre point comptes fonctionnement vi...
# 4130  mandat mobilit bancaire compte joint sign clie...
# 4185  rendez jour cliente souhaite rencontrer faire ...
# 4277  mme souhaite ouvrir compte perso chez car trop...
# 'Point_d_attention_risques' predicted as 'BAQ_Services_Bancaires' : 22 examples.
#                        category  \
# 4966  Point_d_attention_risques
# 4794  Point_d_attention_risques
# 4526  Point_d_attention_risques
# 4467  Point_d_attention_risques
# 4841  Point_d_attention_risques
# 4658  Point_d_attention_risques
# 4864  Point_d_attention_risques
# 4854  Point_d_attention_risques
# 4852  Point_d_attention_risques
# 4836  Point_d_attention_risques
# 4866  Point_d_attention_risques
# 4881  Point_d_attention_risques
# 4800  Point_d_attention_risques
# 4599  Point_d_attention_risques
# 4649  Point_d_attention_risques
# 4457  Point_d_attention_risques
# 4839  Point_d_attention_risques
# 4655  Point_d_attention_risques
# 4549  Point_d_attention_risques
# 4967  Point_d_attention_risques
# 4875  Point_d_attention_risques
# 4840  Point_d_attention_risques
#
#                                                    text
# 4966  mail mr jour veut plus carte gold car gratuite...
# 4794  travaille restauration h tel sequoia disney ch...
# 4526  ouverture compte pro souscription offre propul...
# 4467  cr dit immobilier r alis convention courtier e...
# 4841  jour pr avis maman cliente passe r gularise co...
# 4658  bonjour fait pr immobilier prospect financer r...
# 4864  mme souhaite ouvrir compte perso chez car trop...
# 4854  suite part coll gue a chassaing reprise dossie...
# 4852  couple instance paration procuration comptes d...
# 4836  jour pr avis maman cliente passe r gularise co...
# 4866  mme souhaite ouvrir compte perso chez car trop...
# 4881  rendez octobre point comptes fonctionnement vi...
# 4800  a comptes cheque car compte perso celui termin...
# 4599  client vu rentrer relation eerd a fonctionn e ...
# 4649  rdv ouverture second compte ch autre carte pre...
# 4457   pec exceptionnelle frais mise opposition ch cac
# 4839  jour pr avis maman cliente passe r gularise co...
# 4655  client actuellement recherche active emploie e...
# 4549  propos client changement carte bancaire mozaic...
# 4967  bilan situation fin droit carte mozaic livret ...
# 4875  rendez annuel droit compte client souhaite con...
# 4840  jour pr avis maman cliente passe r gularise co...
# 'Reclamation_Insatisfaction_client' predicted as 'BAQ_Services_Bancaires' : 10 examples.
#                                category  \
# 5260  Reclamation_Insatisfaction_client
# 5240  Reclamation_Insatisfaction_client
# 5257  Reclamation_Insatisfaction_client
# 5158  Reclamation_Insatisfaction_client
# 5199  Reclamation_Insatisfaction_client
# 5226  Reclamation_Insatisfaction_client
# 5258  Reclamation_Insatisfaction_client
# 5154  Reclamation_Insatisfaction_client
# 5263  Reclamation_Insatisfaction_client
# 5259  Reclamation_Insatisfaction_client
#
#                                                    text
# 5260  contente suite fraude cb prise charge poste po...
# 5240  entretien phonique mai monsieur va faire passe...
# 5257  madame a cid ouvrir compte chez afin proc der ...
# 5158  madame souhaitait faire point comptes envisage...
# 5199  client a envoy mail obtenir geste commercial c...
# 5226  cotisation carte gold moitie prix ere annee co...
# 5258  madame a cid ouvrir compte chez afin proc der ...
# 5154                               retro carte effectu
# 5263  mr mme compte egalement a caisse ep servent ep...
# 5259  madame a cid ouvrir compte chez afin proc der ...
# 'Entree_en_relation_Conquetes' predicted as 'Bilan_suivi_relationnel' : 7 examples.
#                           category  \
# 2591  Entree_en_relation_Conquetes
# 2527  Entree_en_relation_Conquetes
# 2447  Entree_en_relation_Conquetes
# 2629  Entree_en_relation_Conquetes
# 2528  Entree_en_relation_Conquetes
# 2682  Entree_en_relation_Conquetes
# 2744  Entree_en_relation_Conquetes
#
#                                                    text
# 2591  mr mme souhaite donner leurs petits enfants k ...
# 2527  client tel bonne relation cr dit agricole cont...
# 2447  rdv arr activit cours auto cole coulommiers pr...
# 2629  mla restitu carte bancaire monsieur aujourd hu...
# 2528  client tel bonne relation cr dit agricole cont...
# 2682  re libataire enfants charge devenu aide soigna...
# 2744  bilan compte regularistion compte frais rembou...
# 'Epargne_terme' predicted as 'Bilan_suivi_relationnel' : 6 examples.
#            category                                               text
# 3170  Epargne_terme               point epargne propo ke p a relancer
# 3447  Epargne_terme  point comptes voir augmentation ovp pel ouvert...
# 3145  Epargne_terme  message r pondeur laiss portable client rappel...
# 3595  Epargne_terme  assurance non a maif rdvs pr fourgous ouv ass ...
# 3833  Epargne_terme                  proposition souscription per mme
# 3397  Epargne_terme  rdv arr activit cours auto cole coulommiers pr...
# 'Non_specifie_Credit_Assurance_Epargne_' predicted as 'Bilan_suivi_relationnel' : 14 examples.
#                                     category  \
# 4399  Non_specifie_Credit_Assurance_Epargne_
# 4268  Non_specifie_Credit_Assurance_Epargne_
# 4211  Non_specifie_Credit_Assurance_Epargne_
# 4364  Non_specifie_Credit_Assurance_Epargne_
# 4366  Non_specifie_Credit_Assurance_Epargne_
# 4311  Non_specifie_Credit_Assurance_Epargne_
# 4254  Non_specifie_Credit_Assurance_Epargne_
# 4092  Non_specifie_Credit_Assurance_Epargne_
# 4275  Non_specifie_Credit_Assurance_Epargne_
# 4091  Non_specifie_Credit_Assurance_Epargne_
# 4246  Non_specifie_Credit_Assurance_Epargne_
# 4253  Non_specifie_Credit_Assurance_Epargne_
# 4352  Non_specifie_Credit_Assurance_Epargne_
# 4407  Non_specifie_Credit_Assurance_Epargne_
#
#                                                    text
# 4399  mr rmcl retraite mai mme maroquinerie orgues p...
# 4268  contact tel mr proposition bilan assurance r p...
# 4211  appelle jour remboursement anticip date valeur...
# 4364  echange mr ok convenir rdv avant fin mars a re...
# 4366  rendez faire point annuel pargne madame rappel...
# 4311  re libataire enfants charge devenu aide soigna...
# 4254  madame venue faire point compte retraite rever...
# 4092  rappelle gobs euros lef r serve euros fait pr ...
# 4275  re u madame aujourd hui planifier rendez but a...
# 4091  rappelle gobs euros lef r serve euros fait pr ...
# 4246  entretien phonique juin tude placement refus c...
# 4253  madame venue faire point compte retraite rever...
# 4352  client vit region ok faire point epargne dynam...
# 4407  a temps moment assur maif convenu rappelle fin...
# 'Point_d_attention_risques' predicted as 'Bilan_suivi_relationnel' : 14 examples.
#                        category  \
# 4530  Point_d_attention_risques
# 4647  Point_d_attention_risques
# 4898  Point_d_attention_risques
# 4890  Point_d_attention_risques
# 4891  Point_d_attention_risques
# 4860  Point_d_attention_risques
# 4828  Point_d_attention_risques
# 4771  Point_d_attention_risques
# 4645  Point_d_attention_risques
# 4952  Point_d_attention_risques
# 4743  Point_d_attention_risques
# 4767  Point_d_attention_risques
# 4531  Point_d_attention_risques
# 4807  Point_d_attention_risques
#
#                                                    text
# 4530  madame sans emploi depuis septembre a fini for...
# 4647  monsieur a appr ci appel courtoisie a fait par...
# 4898  re libataire enfants charge devenu aide soigna...
# 4890  echange tel concernant situation proposition r...
# 4891  echange tel concernant situation proposition r...
# 4860  re u madame aujourd hui planifier rendez but a...
# 4828  rdv jour casse suite recrutement bpd part immi...
# 4771  rdv inutile pensaient avoir encore ivp cl tur ...
# 4645  arret activit chomage partiel salari report pr...
# 4952  rendez faire point annuel pargne madame rappel...
# 4743  gestion compte jour sujet difficult financi re...
# 4767  arr activit depuis mardi report pr ts pro mois...
# 4531  madame sans emploi depuis septembre a fini for...
# 4807  patrimoine immobilier financier important mr a...
# 'Assurance_de_Personnes' predicted as 'Credit_conso' : 7 examples.
#                    category                                               text
# 487  Assurance_de_Personnes  cliente re u jour montage cr dit conso mois me...
# 678  Assurance_de_Personnes  vu janvier pr conso deux propositions mois ann...
# 533  Assurance_de_Personnes  remboursement pret conso jour projet nouveau p...
# 567  Assurance_de_Personnes               appel black friday projet depose pj
# 716  Assurance_de_Personnes  monsieur projet cr dit conso locataire mois ga...
# 519  Assurance_de_Personnes  madame caron va avoir mobilite pro debut janvi...
# 576  Assurance_de_Personnes  projet pr paration obs ques financement caveau...
# 'Assurance_de_Personnes' predicted as 'Credit_habitat' : 10 examples.
#                    category                                               text
# 598  Assurance_de_Personnes  madame a vendu maison a cerilly souhaite achet...
# 608  Assurance_de_Personnes  mr chauffeur poids lourds courcelles cdi depui...
# 727  Assurance_de_Personnes  mr travaille int rim bouygue doit boucher cdi ...
# 582  Assurance_de_Personnes  mme air caraibes temps partiel mr mut paris ve...
# 556  Assurance_de_Personnes  mademoiselle esteves travaille mairie aubi re ...
# 728  Assurance_de_Personnes  mr travaille int rim bouygue doit boucher cdi ...
# 470  Assurance_de_Personnes  entretien phonique monsieur concernant demande...
# 471  Assurance_de_Personnes  entretien phonique monsieur concernant demande...
# 408  Assurance_de_Personnes  cliente cliente re u octobre ren gociation cr ...
# 621  Assurance_de_Personnes  appelle car madame ligible offre commerciale m...
# 'Credit_travaux' predicted as 'Credit_habitat' : 5 examples.
#             category                                               text
# 2188  Credit_travaux  instruction pr travaux compl mentaire op ratio...
# 2140  Credit_travaux  rendez client diff rents projets client doit r...
# 2165  Credit_travaux  rendez pris faire connaissance projet extensio...
# 2152  Credit_travaux  rdv mr lecuyer maman separe mle quid pr ts mad...
# 2177  Credit_travaux  vda tel mme ciccone nagement boutique villiers...
# 'Credit_vehicule' predicted as 'Credit_habitat' : 5 examples.
#              category                                               text
# 2193  Credit_vehicule  rendez client diff rents projets client doit r...
# 2211  Credit_vehicule  entretien phonique monsieur concernant demande...
# 2266  Credit_vehicule  client routier fin int rim mi dec gagnait env ...
# 2214  Credit_vehicule  cdi ime marmanhac depuis ans enfants pension e...
# 2217  Credit_vehicule  mme locataire moutier rozeille cdi chez chauss...
# 'Entree_en_relation_Conquetes' predicted as 'Credit_habitat' : 15 examples.
#                           category  \
# 2781  Entree_en_relation_Conquetes
# 2484  Entree_en_relation_Conquetes
# 2663  Entree_en_relation_Conquetes
# 2510  Entree_en_relation_Conquetes
# 2551  Entree_en_relation_Conquetes
# 2552  Entree_en_relation_Conquetes
# 2407  Entree_en_relation_Conquetes
# 2531  Entree_en_relation_Conquetes
# 2784  Entree_en_relation_Conquetes
# 2339  Entree_en_relation_Conquetes
# 2549  Entree_en_relation_Conquetes
# 2301  Entree_en_relation_Conquetes
# 2550  Entree_en_relation_Conquetes
# 2696  Entree_en_relation_Conquetes
# 2350  Entree_en_relation_Conquetes
#
#                                                    text
# 2781  fait simul habitat terrain constructuon k tx m...
# 2484  rdv couple concubinage prospect enfant ans pro...
# 2663  demande financement suite achat villa a roujan...
# 2510  rendez pris faire connaissance projet extensio...
# 2551  mr mme mari sans contrat mariage filles dont c...
# 2552  mr mme mari sans contrat mariage filles dont c...
# 2407  monsieur projet achat r sidence principale don...
# 2531  mme maries enfants petits enfants sci balia en...
# 2784  client travaille chez limagrain charg cr er no...
# 2339  cliente divorcee enfants vivent madame salaire...
# 2549  cliente com dienne intermittente spectacle th ...
# 2301  monsieur intermittent spectacle depuis juin pl...
# 2550  mr mme mari sans contrat mariage filles dont c...
# 2696  expliqu client pourquoi tarification apres quo...
# 2350  mme vus jour validation lep versement livret a...
# 'Epargne_disponible' predicted as 'Credit_habitat' : 7 examples.
#                 category                                               text
# 3032  Epargne_disponible  client tel pr senter suite mdc cr dit imp a pr...
# 3126  Epargne_disponible  david rdv suite asa optimisation pargne livret...
# 3031  Epargne_disponible  client tel pr senter suite mdc cr dit imp a pr...
# 2895  Epargne_disponible  mlle vue jour point pargne banque postale proj...
# 3127  Epargne_disponible  david rdv suite asa optimisation pargne livret...
# 2831  Epargne_disponible  mme vus jour validation lep versement livret a...
# 2832  Epargne_disponible  mme vus jour validation lep versement livret a...
# 'Epargne_terme' predicted as 'Credit_habitat' : 9 examples.
#            category                                               text
# 3761  Epargne_terme  rencontre jour projet immobilier travaux ans a...
# 3760  Epargne_terme  rencontre jour projet immobilier travaux ans a...
# 3759  Epargne_terme  rencontre jour projet immobilier travaux ans a...
# 3471  Epargne_terme  projet immobilier voqu jour activation f vefa ...
# 3302  Epargne_terme  madame actuellement contrat cdi depuis mois ao...
# 3561  Epargne_terme  client vend r sidence secondaire revoir client...
# 3169  Epargne_terme  rdv tel faire point pargne facturation projet ...
# 3889  Epargne_terme  patrimoine ok appartement a st pierre mer prop...
# 3890  Epargne_terme  patrimoine ok appartement a st pierre mer prop...
# 'Evenements_de_vie' predicted as 'Credit_habitat' : 6 examples.
#                category                                               text
# 3975  Evenements_de_vie  va signer vente rp k devrait recevoir somme al...
# 3949  Evenements_de_vie  point situation patrimoniale fiscale monsieur ...
# 4026  Evenements_de_vie  ss maman partage cours vente bien cours france...
# 3972  Evenements_de_vie  cliente com dienne intermittente spectacle th ...
# 4029  Evenements_de_vie  viens avoir madame phone concernant erreur vir...
# 3964  Evenements_de_vie  client vend r sidence secondaire revoir client...
# 'Non_specifie_Credit_Assurance_Epargne_' predicted as 'Credit_habitat' : 9 examples.
#                                     category  \
# 4327  Non_specifie_Credit_Assurance_Epargne_
# 4149  Non_specifie_Credit_Assurance_Epargne_
# 4192  Non_specifie_Credit_Assurance_Epargne_
# 4321  Non_specifie_Credit_Assurance_Epargne_
# 4217  Non_specifie_Credit_Assurance_Epargne_
# 4173  Non_specifie_Credit_Assurance_Epargne_
# 4322  Non_specifie_Credit_Assurance_Epargne_
# 4409  Non_specifie_Credit_Assurance_Epargne_
# 4411  Non_specifie_Credit_Assurance_Epargne_
#
#                                                    text
# 4327   presentation point pret hab deblocage assurance
# 4149  cliente pacse enfants multibancarisee mr bnp c...
# 4192  demande pr conso ans achat lectrom nager cdi a...
# 4321  client routier fin int rim mi dec gagnait env ...
# 4217  appelle car madame ligible offre commerciale m...
# 4173  rdv couple concubinage prospect enfant ans pro...
# 4322  expliqu client pourquoi tarification apres quo...
# 4409  client travaille chez limagrain charg cr er no...
# 4411  rachat anticipe pret immo locatif suite donati...
# 'Point_d_attention_risques' predicted as 'Credit_habitat' : 15 examples.
#                        category  \
# 4769  Point_d_attention_risques
# 4431  Point_d_attention_risques
# 4756  Point_d_attention_risques
# 4447  Point_d_attention_risques
# 4664  Point_d_attention_risques
# 4430  Point_d_attention_risques
# 4441  Point_d_attention_risques
# 4545  Point_d_attention_risques
# 4641  Point_d_attention_risques
# 4479  Point_d_attention_risques
# 4518  Point_d_attention_risques
# 4804  Point_d_attention_risques
# 4497  Point_d_attention_risques
# 4757  Point_d_attention_risques
# 4764  Point_d_attention_risques
#
#                                                    text
# 4769  appelle car madame ligible offre commerciale m...
# 4431  monsieur intermittent spectacle depuis juin pl...
# 4756  mr chauffeur poids lourds courcelles cdi depui...
# 4447  rdv tel faire point pargne facturation projet ...
# 4664  appelle jour mai essayer trouver solution conc...
# 4430  monsieur intermittent spectacle depuis juin pl...
# 4441  client jour r am nagement alors pr totalement ...
# 4545  cliente vient nager nouvelle r sidence princip...
# 4641                     clients restent chez assureur
# 4479  mme vus jour validation lep versement livret a...
# 4518  entretien phonique monsieur concernant demande...
# 4804  echange tel jour client client souhaitait savo...
# 4497                                         refus end
# 4757  mr chauffeur poids lourds courcelles cdi depui...
# 4764  mr mme mari sans contrat mariage filles dont c...
# 'Assurance_de_Biens' predicted as 'Entree_en_relation_Conquetes' : 15 examples.
#                category                                               text
# 42   Assurance_de_Biens  cliente mme enfants ans fille ans gar actuelle...
# 138  Assurance_de_Biens  cliente ch mage depuis plus an suite soucis a ...
# 98   Assurance_de_Biens  cliente voulait faire point assurance vie car ...
# 217  Assurance_de_Biens  refus assurances client satisfait fid maaf sim...
# 159  Assurance_de_Biens  projet achat v hicule allemagne audi a sportba...
# 398  Assurance_de_Biens  second rendez suite entr e relation madame sou...
# 189  Assurance_de_Biens  vu madame ouverture livret a fille proposition...
# 33   Assurance_de_Biens  nouvelle client financ rp mandat macron ok ouv...
# 124  Assurance_de_Biens  re u jour faire point comptes travaill r am na...
# 253  Assurance_de_Biens  rendez demande pret travaux ans r serve black ...
# 173  Assurance_de_Biens  madame enfants ans ans fille bordeaux chercheu...
# 346  Assurance_de_Biens  fait partie communaut gens voyage entraide fin...
# 32   Assurance_de_Biens  nouvelle client financ rp mandat macron ok ouv...
# 345  Assurance_de_Biens  fait partie communaut gens voyage entraide fin...
# 382  Assurance_de_Biens  vu mme duc st nicolas langogne duc arc ciel ch...
# 'Assurance_de_Personnes' predicted as 'Entree_en_relation_Conquetes' : 16 examples.
#                    category                                               text
# 405  Assurance_de_Personnes  cliente int rim depuis aout projet revendre rp...
# 737  Assurance_de_Personnes  fait partie communaut gens voyage entraide fin...
# 704  Assurance_de_Personnes  vient emm nager r gion client ca brie picardie...
# 552  Assurance_de_Personnes  madame enfants ans ans fille bordeaux chercheu...
# 636  Assurance_de_Personnes  rendez demande pret travaux ans r serve black ...
# 481  Assurance_de_Personnes  mess port mme proposer offre gad premi re ann ...
# 639  Assurance_de_Personnes  rendez demande pret travaux ans r serve black ...
# 507  Assurance_de_Personnes                            propo mutuel sous cmcu
# 771  Assurance_de_Personnes                 monsieur poss mine mme a chez axa
# 581  Assurance_de_Personnes  mr compte a compte joint mr mme a fille ans co...
# 480  Assurance_de_Personnes  mess port mme proposer offre gad premi re ann ...
# 638  Assurance_de_Personnes  rendez demande pret travaux ans r serve black ...
# 553  Assurance_de_Personnes  madame enfants ans ans fille bordeaux chercheu...
# 429  Assurance_de_Personnes  cliente mme enfants ans fille ans gar actuelle...
# 748  Assurance_de_Personnes  mme va r cup rer exploitation agricole vignes ...
# 747  Assurance_de_Personnes  mme va r cup rer exploitation agricole vignes ...
# 'BAQ_Services_Bancaires' predicted as 'Entree_en_relation_Conquetes' : 9 examples.
#                     category  \
# 799   BAQ_Services_Bancaires
# 965   BAQ_Services_Bancaires
# 1122  BAQ_Services_Bancaires
# 962   BAQ_Services_Bancaires
# 871   BAQ_Services_Bancaires
# 1084  BAQ_Services_Bancaires
# 812   BAQ_Services_Bancaires
# 1176  BAQ_Services_Bancaires
# 917   BAQ_Services_Bancaires
#
#                                                    text
# 799   cliente va refonctionner a fait mea culpa oc n...
# 965   client a ouvert compte afin domicilier flux ac...
# 1122  mr mme vus jour fils a projet immo mme r lait ...
# 962   vu madame ouverture livret a fille proposition...
# 871   reco soeur actuellement bac souhaite aller uni...
# 1084  ere mineur ouverture dav car mle commence trav...
# 812   nouvelle client financ rp mandat macron ok ouv...
# 1176  rendez annuel gestion comptes professionnels p...
# 917   mme a effectue mandat macron souhaite conserve...
# 'Bilan_suivi_relationnel' predicted as 'Entree_en_relation_Conquetes' : 9 examples.
#                      category  \
# 1433  Bilan_suivi_relationnel
# 1471  Bilan_suivi_relationnel
# 1458  Bilan_suivi_relationnel
# 1196  Bilan_suivi_relationnel
# 1432  Bilan_suivi_relationnel
# 1329  Bilan_suivi_relationnel
# 1474  Bilan_suivi_relationnel
# 1245  Bilan_suivi_relationnel
# 1376  Bilan_suivi_relationnel
#
#                                                    text
# 1433  rendez janvier ouverture compte ch personnel m...
# 1471  mme coiffeuse cdi depuis ans couple a deux fil...
# 1458  cliente a touch h ritage maman e a longtemps f...
# 1196  a ans reconversion pro agence mandataire r sea...
# 1432  rendez janvier ouverture compte ch personnel m...
# 1329  re u mr mme jour rdv mr mme mari paration bien...
# 1474  fait partie communaut gens voyage entraide fin...
# 1245  cliente voulait faire point assurance vie car ...
# 1376  mme a souhait rencontrer faire connaissance e ...
# 'Credit_habitat' predicted as 'Entree_en_relation_Conquetes' : 13 examples.
#             category                                               text
# 2091  Credit_habitat  mr agent sncf depuis mme cdi admr depuis enfan...
# 1744  Credit_habitat  couple paration simul faite rachat soulte mons...
# 1912  Credit_habitat  re ois aujourd hui monsieur madame actuellemen...
# 1951  Credit_habitat  dossier vu demande caution projet ke cliente i...
# 2016  Credit_habitat  entretien rapide savoir pouvait transf rer dro...
# 1922  Credit_habitat  ream ok defensif poste vu sylvie ouverture liv...
# 1989  Credit_habitat  client vit concubinage enfant charge ans fille...
# 1771  Credit_habitat  nouvelle client financ rp mandat macron ok ouv...
# 1768  Credit_habitat  projet achat maison quand cdi mlle surveillant...
# 1800  Credit_habitat  rachat pr travaille chez michelin mme mairie e...
# 2009  Credit_habitat  jour suite virt notaire rbst anticip cr dits m...
# 2066  Credit_habitat  mr mme vus jour fils a projet immo mme r lait ...
# 1835  Credit_habitat  re u jour monsieur fait simulation pr habitat ...
# 'Epargne_disponible' predicted as 'Entree_en_relation_Conquetes' : 16 examples.
#                 category                                               text
# 3118  Epargne_disponible  rdv recu fille cliente bcpe transfo cpte joint...
# 3029  Epargne_disponible  achat rp a aubiere mme prospect a faire transf...
# 3021  Epargne_disponible  rencontr mr directeur lycee agropolis tr bon n...
# 3022  Epargne_disponible  rencontr mr directeur lycee agropolis tr bon n...
# 2938  Epargne_disponible  vu madame ouverture livret a fille proposition...
# 2983  Epargne_disponible  commerce materiaux construction mme retrait e ...
# 3100  Epargne_disponible  madame sollicite occuper cl ture compte caisse...
# 3046  Epargne_disponible  vient emm nager r gion client ca brie picardie...
# 2888  Epargne_disponible  doit ramener irpp recepisse demande cni car cn...
# 2952  Epargne_disponible  travaux maison moment donc a temps pense ouvri...
# 2790  Epargne_disponible  mme a souhait cl turer ldd tout mettre compte ...
# 2936  Epargne_disponible  ream ok defensif poste vu sylvie ouverture liv...
# 3038  Epargne_disponible  mme retrait e prof coles ans veuve depuis sept...
# 2971  Epargne_disponible  refus assurances client satisfait fid maaf sim...
# 2969  Epargne_disponible  re u mr mme jour rdv mr mme mari paration bien...
# 3074  Epargne_disponible  mme coiffeuse cdi depuis ans couple a deux fil...
# 'Epargne_terme' predicted as 'Entree_en_relation_Conquetes' : 26 examples.
# ...
# 502  Assurance_de_Personnes  re u cliente afin diversifier placements propo...
# 464  Assurance_de_Personnes  mme venu bilan pargne livret a tait plein souh...
# 453  Assurance_de_Personnes  deux propos mutuelles integrale initiale soins...
# 668  Assurance_de_Personnes  message tel client jour rdv assurances ca appe...
# 465  Assurance_de_Personnes  mme venu bilan pargne livret a tait plein souh...
# 'Bilan_suivi_relationnel' predicted as 'Non_specifie_Credit_Assurance_Epargne_' : 12 examples.
#                      category  \
# 1362  Bilan_suivi_relationnel
# 1223  Bilan_suivi_relationnel
# 1203  Bilan_suivi_relationnel
# 1489  Bilan_suivi_relationnel
# 1336  Bilan_suivi_relationnel
# 1482  Bilan_suivi_relationnel
# 1298  Bilan_suivi_relationnel
# 1389  Bilan_suivi_relationnel
# 1274  Bilan_suivi_relationnel
# 1319  Bilan_suivi_relationnel
# 1371  Bilan_suivi_relationnel
# 1456  Bilan_suivi_relationnel
#
#                                                    text
# 1362  monsieur a rappel suite message laiss aso hier...
# 1223  deux propos mutuelles integrale initiale soins...
# 1203  rencontrer monsieur janvier proposition bilan ...
# 1489  cliente tel suite mail maman petite fille mari...
# 1336  projet travaux rp environ mois oct refus propo...
# 1482  mr journaliste rmb notamment essaie r duire li...
# 1298  contact client suite fmc solde tout compte sui...
# 1389  proposition rdv bilan assurance veux changer a...
# 1274  nouveau message laiss portable car clients inj...
# 1319  mr a contrats assurance concurrence axa propo ...
# 1371  compte rendu activit appelle client jour messa...
# 1456  mme contente appel contente changer reprendre ...
# 'Credit_habitat' predicted as 'Non_specifie_Credit_Assurance_Epargne_' : 5 examples.
#             category                                               text
# 2104  Credit_habitat  dossier apr r ception ensemble ments mai clien...
# 1819  Credit_habitat  mme venu bilan pargne livret a tait plein souh...
# 2118  Credit_habitat  rendez initiative car pel monsieur arrive ans ...
# 2106  Credit_habitat  a revoir mai car monsieur doit toucher retrait...
# 1790  Credit_habitat  appel monsieur rivelois mars suite vente bien ...
# 'Epargne_terme' predicted as 'Non_specifie_Credit_Assurance_Epargne_' : 10 examples.
#            category                                               text
# 3668  Epargne_terme  suite a pret realise chez point placements aut...
# 3703  Epargne_terme  proposition rdv bilan assurance veux changer a...
# 3580  Epargne_terme  a retraite depuis novembre mr instance divorce...
# 3669  Epargne_terme  suite a pret realise chez point placements aut...
# 3150  Epargne_terme  mme veuve depuis revu clause b ficiaire consei...
# 3156  Epargne_terme  rencontrer monsieur janvier proposition bilan ...
# 3683  Epargne_terme  mme tenait routier pont allier monsieur tait p...
# 3321  Epargne_terme                       suite entretien pro opinion
# 3158  Epargne_terme  rencontrer monsieur janvier proposition bilan ...
# 3566  Epargne_terme  projet travaux rp environ mois oct refus propo...
# 'Point_d_attention_risques' predicted as 'Non_specifie_Credit_Assurance_Epargne_' : 8 examples.
#                        category  \
# 4689  Point_d_attention_risques
# 4806  Point_d_attention_risques
# 4637  Point_d_attention_risques
# 4782  Point_d_attention_risques
# 4741  Point_d_attention_risques
# 4786  Point_d_attention_risques
# 4936  Point_d_attention_risques
# 4428  Point_d_attention_risques
#
#                                                    text
# 4689  client pargne arriv terme a donc souhait voir ...
# 4806  mme tenait routier pont allier monsieur tait p...
# 4637  vu ric durand mise place pr gestion budget mis...
# 4782  vu accueil suite atd imp ts cours doit r gular...
# 4741  projet travaux rp environ mois oct refus propo...
# 4786  entreprise multibancaris e demande ch ancier p...
# 4936  relance jour concernant installation mme propo...
# 4428  mme veuve depuis revu clause b ficiaire consei...
# 'Assurance_de_Biens' predicted as 'Point_d_attention_risques' : 16 examples.
#                category                                               text
# 379  Assurance_de_Biens  arr maladie jusqu voir prolongation litige emp...
# 148  Assurance_de_Biens  monsieur fait demande souscription assurance a...
# 113  Assurance_de_Biens  pr paration rdv non honor sortie pr contentieu...
# 381  Assurance_de_Biens  arr maladie jusqu voir prolongation litige emp...
# 304  Assurance_de_Biens                                       refus devis
# 376  Assurance_de_Biens  cliente souhaite rencontrer conseiller fin pla...
# 202  Assurance_de_Biens  ch ques impay e chacun question sce ch ques sa...
# 333  Assurance_de_Biens  monsieur travail actuellement surveillant lyc ...
# 380  Assurance_de_Biens  arr maladie jusqu voir prolongation litige emp...
# 192  Assurance_de_Biens  rendez pris initiative madame tablir point ann...
# 263  Assurance_de_Biens  rdv pt comptes patrimoine ok demande rbt e cb ...
# 252  Assurance_de_Biens  tr pris construction finalement assurer maison...
# 317  Assurance_de_Biens  madame tient contrat obs ques autre tablisseme...
# 286  Assurance_de_Biens  mme pr sente seule aujourd hui ouvrir compte j...
# 203  Assurance_de_Biens  ch ques impay e chacun question sce ch ques sa...
# 36   Assurance_de_Biens  int ress parts sociales instant assurance habi...
# 'Assurance_de_Personnes' predicted as 'Point_d_attention_risques' : 12 examples.
#                    category                                               text
# 683  Assurance_de_Personnes  traitement motif contact mars contact a carte ...
# 684  Assurance_de_Personnes  traitement motif contact mars contact a carte ...
# 773  Assurance_de_Personnes  a souhaite virer ke vers sete multibancarisee ...
# 499  Assurance_de_Personnes  pr paration rdv non honor sortie pr contentieu...
# 491  Assurance_de_Personnes  modif carte soci taire gold client voulait cou...
# 635  Assurance_de_Personnes         propo mutuel refus car euros mois travail
# 651  Assurance_de_Personnes  client a souscrit mutuelle crcam rencontrons j...
# 520  Assurance_de_Personnes             envoi fiches refus ade laure compigne
# 613  Assurance_de_Personnes  cliente accord passer cac budget prot ge a fai...
# 435  Assurance_de_Personnes  proposition client int ress mutuelle entrepris...
# 708  Assurance_de_Personnes  madame tient contrat obs ques autre tablisseme...
# 498  Assurance_de_Personnes  pr paration rdv non honor sortie pr contentieu...
# 'BAQ_Services_Bancaires' predicted as 'Point_d_attention_risques' : 21 examples.
#                     category  \
# 1022  BAQ_Services_Bancaires
# 1051  BAQ_Services_Bancaires
# 1177  BAQ_Services_Bancaires
# 806   BAQ_Services_Bancaires
# 1172  BAQ_Services_Bancaires
# 863   BAQ_Services_Bancaires
# 942   BAQ_Services_Bancaires
# 873   BAQ_Services_Bancaires
# 1141  BAQ_Services_Bancaires
# 979   BAQ_Services_Bancaires
# 1123  BAQ_Services_Bancaires
# 1002  BAQ_Services_Bancaires
# 1003  BAQ_Services_Bancaires
# 1001  BAQ_Services_Bancaires
# 1121  BAQ_Services_Bancaires
# 1119  BAQ_Services_Bancaires
# 883   BAQ_Services_Bancaires
# 1069  BAQ_Services_Bancaires
# 872   BAQ_Services_Bancaires
# 1082  BAQ_Services_Bancaires
# 995   BAQ_Services_Bancaires
#
#                                                    text
# 1022  mv demander faire point vue compte plus plus b...
# 1051  rdv jour point comptes motif contact budget pr...
# 1177  entretien phonique entrant monsieur comprenez ...
# 806   agit avoirs netflix non rbsts pr vements deman...
# 1172  rdv versement contrat p alex veuve depuis cont...
# 863   monsieur phone couvert passager mis place jour...
# 942   client a octobre afin demander blocage carte b...
# 873   modif carte soci taire gold client voulait cou...
# 1141  quetel a suite bit depuis plusieurs mois dit p...
# 979   ch ques impay e chacun question sce ch ques sa...
# 1123  monsieur travail actuellement surveillant lyc ...
# 1002  cliente accord passer cac budget prot ge a fai...
# 1003  cliente accord passer cac budget prot ge a fai...
# 1001  cliente accord passer cac budget prot ge a fai...
# 1121  utilisation abusive carte commande nouvelle ca...
# 1119  utilisation abusive carte commande nouvelle ca...
# 883   monsieur associ p re fils pr vement priv mois ...
# 1069  mme pr sente seule aujourd hui ouvrir compte j...
# 872   modif carte soci taire gold client voulait cou...
# 1082  honorer loyer impay refus augmentation oc car ...
# 995   sans emploi revenu aah vit concubinage gomis f...
# 'Bilan_suivi_relationnel' predicted as 'Point_d_attention_risques' : 12 examples.
#                      category  \
# 1520  Bilan_suivi_relationnel
# 1262  Bilan_suivi_relationnel
# 1272  Bilan_suivi_relationnel
# 1248  Bilan_suivi_relationnel
# 1332  Bilan_suivi_relationnel
# 1234  Bilan_suivi_relationnel
# 1270  Bilan_suivi_relationnel
# 1491  Bilan_suivi_relationnel
# 1261  Bilan_suivi_relationnel
# 1197  Bilan_suivi_relationnel
# 1364  Bilan_suivi_relationnel
# 1271  Bilan_suivi_relationnel
#
#                                                    text
# 1520  entretien phonique entrant monsieur comprenez ...
# 1262  madame surendett e augmentation couvert jusque...
# 1272  com tel soeur a procuration faire point situat...
# 1248  partie pro client a quelques jours couvert but...
# 1332  client jour souhaite changer assureur car conn...
# 1234  cliente demand rendez faire point comptes a de...
# 1270  cliente a pris rendez faire point rendement pa...
# 1491                        transporteur impact moment
# 1261  madame surendett e augmentation couvert jusque...
# 1197       cliente injoignable num ro figurant dossier
# 1364  mv demander faire point vue compte plus plus b...
# 1271  explications situations compte penses impr vue...
# 'Credit_habitat' predicted as 'Point_d_attention_risques' : 9 examples.
#             category                                               text
# 2070  Credit_habitat  client revenu voir projet immo terrasses eugen...
# 1961  Credit_habitat  suite coup phone re u monsieur jour pret rembo...
# 1919  Credit_habitat  monsieur client lcl car financer r sidence pri...
# 2071  Credit_habitat  client revenu voir projet immo terrasses eugen...
# 1916  Credit_habitat  suite paration vente bien cours signature fin ...
# 1853  Credit_habitat  mr sqpr contrat finit mois assure bient nouvel...
# 1949  Credit_habitat  ch ques impay e chacun question sce ch ques sa...
# 1977  Credit_habitat  client pr sente aujourd hui car ach r sidence ...
# 2069  Credit_habitat  client revenu voir projet immo terrasses eugen...
# 'Entree_en_relation_Conquetes' predicted as 'Point_d_attention_risques' : 6 examples.
#                           category  \
# 2460  Entree_en_relation_Conquetes
# 2493  Entree_en_relation_Conquetes
# 2764  Entree_en_relation_Conquetes
# 2381  Entree_en_relation_Conquetes
# 2478  Entree_en_relation_Conquetes
# 2736  Entree_en_relation_Conquetes
#
#                                                    text
# 2460  cliente a euros vivre mois fois tous pr vement...
# 2493  mme cont parental doit reprendre travail janvi...
# 2764  arr maladie jusqu voir prolongation litige emp...
# 2381  recommand mr france depuis avril location loye...
# 2478          mise place couvert passager compte joint
# 2736  point perp info per reste perp besoin fiscalis...
# 'Epargne_terme' predicted as 'Point_d_attention_risques' : 16 examples.
#            category                                               text
# 3523  Epargne_terme  nouement plan vert vitalit madame demand sous ...
# 3770  Epargne_terme  traitement motif contact mars contact a carte ...
# 3412  Epargne_terme  proposition versement assurance vie ke compte ...
# 3276  Epargne_terme  part sociale envoy cof jour permettre cl ture ...
# 3368  Epargne_terme  monsieur associ p re fils pr vement priv mois ...
# 3210  Epargne_terme  int ress parts sociales instant assurance habi...
# 3872  Epargne_terme  alex cliente a macif veut changer interessee p...
# 3411  Epargne_terme  proposition versement assurance vie ke compte ...
# 3814  Epargne_terme  madame tient contrat obs ques autre tablisseme...
# 3657  Epargne_terme  tr pris construction finalement assurer maison...
# 3495  Epargne_terme  suite paration vente bien cours signature fin ...
# 3680  Epargne_terme  client a souscrit mutuelle crcam rencontrons j...
# 3381  Epargne_terme  envoi explications mail sujet calcul cotisatio...
# 3744  Epargne_terme  rencontre jour clients font part leurs difficu...
# 3277  Epargne_terme  part sociale envoy cof jour permettre cl ture ...
# 3694  Epargne_terme  mme sort situation surendettement fait a deux ...
# 'Non_specifie_Credit_Assurance_Epargne_' predicted as 'Point_d_attention_risques' : 14 examples.
#                                     category  \
# 4271  Non_specifie_Credit_Assurance_Epargne_
# 4351  Non_specifie_Credit_Assurance_Epargne_
# 4406  Non_specifie_Credit_Assurance_Epargne_
# 4397  Non_specifie_Credit_Assurance_Epargne_
# 4200  Non_specifie_Credit_Assurance_Epargne_
# 4140  Non_specifie_Credit_Assurance_Epargne_
# 4324  Non_specifie_Credit_Assurance_Epargne_
# 4144  Non_specifie_Credit_Assurance_Epargne_
# 4374  Non_specifie_Credit_Assurance_Epargne_
# 4139  Non_specifie_Credit_Assurance_Epargne_
# 4145  Non_specifie_Credit_Assurance_Epargne_
# 4138  Non_specifie_Credit_Assurance_Epargne_
# 4153  Non_specifie_Credit_Assurance_Epargne_
# 4396  Non_specifie_Credit_Assurance_Epargne_
#
#                                                    text
# 4271  taux dernier cr dit a bas faudra prochaine dem...
# 4351  cliente envisage demenagement plus grand proje...
# 4406  proposition budget prot g monsieur r fl chit d...
# 4397  entretien phonique entrant monsieur comprenez ...
# 4200  client jour souhaite changer assureur car conn...
# 4140  mise jour ok a pr voir rdv ass car a dej tract...
# 4324  alex cliente a macif veut changer interessee p...
# 4144  cliente jour phone veut pargner pargne autre b...
# 4374  dav livret a poste cliente occupe cl turer rev...
# 4139  madame surendett e augmentation couvert jusque...
# 4145  cliente jour phone veut pargner pargne autre b...
# 4138  madame surendett e augmentation couvert jusque...
# 4153  com tel soeur a procuration faire point situat...
# 4396  entretien phonique entrant monsieur comprenez ...
# 'Reclamation_Insatisfaction_client' predicted as 'Point_d_attention_risques' : 7 examples.
#                                category  \
# 5157  Reclamation_Insatisfaction_client
# 5160  Reclamation_Insatisfaction_client
# 5246  Reclamation_Insatisfaction_client
# 5247  Reclamation_Insatisfaction_client
# 5224  Reclamation_Insatisfaction_client
# 5149  Reclamation_Insatisfaction_client
# 5164  Reclamation_Insatisfaction_client
#
#                                                    text
# 5157  re u aujourd hui recommand monsieur madame dem...
# 5160  pr paration rdv non honor sortie pr contentieu...
# 5246  dav livret a poste cliente occupe cl turer rev...
# 5247  cl ture pel faite novembre suite r ception cou...
# 5224  monsieur travail actuellement surveillant lyc ...
# 5149  suite mails chang tarification entretien phoni...
# 5164                                      voir tourisk
# 'Entree_en_relation_Conquetes' predicted as 'Projet_exceptionnel_' : 6 examples.
#                           category  \
# 2592  Entree_en_relation_Conquetes
# 2457  Entree_en_relation_Conquetes
# 2368  Entree_en_relation_Conquetes
# 2490  Entree_en_relation_Conquetes
# 2369  Entree_en_relation_Conquetes
# 2346  Entree_en_relation_Conquetes
#
#                                                    text
# 2592  client a vendu murs hotel acotel a fait donati...
# 2457                r transmission patrimonial enfants
# 2368  mr vit seul proprio rp terrains seul revenus m...
# 2490  compte principale banque populaire client ca s...
# 2369  mr vit seul proprio rp terrains seul revenus m...
# 2346  re u bonjour epouse francoise vient deceder pa...

# %% [markdown]
# ## graphique des métrics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.figure(figsize=(8, 5))

df = pd.DataFrame({"Estimater": column_names, 
                   "Accuracy": entries
                  })

sns.barplot(x='Estimater', y='Accuracy', data=df)

print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-6af1b00c0a74> in <module>
#       5 plt.figure(figsize=(8, 5))
#       6
# ----> 7 df = pd.DataFrame({"Estimater": column_names,
#       8                    "Accuracy": entries
#       9                   })
#
# NameError: name 'column_names' is not defined

# %% [markdown]
# # TEST RESEAU NEURONO AVEC BERT

# %%
import torch
from tqdm.notebook import tqdm

from transformers import BertTokenizer
from torch.utils.data import TensorDataset

from transformers import BertForSequenceClassification

# %%
possible_labels = df.category.unique()

label_dict = {}
for index, possible_label in enumerate(possible_labels):
    label_dict[possible_label] = index
label_dict
# Out:
# {'Assurance_de_Biens': 0,
#  'Assurance_de_Personnes': 1,
#  'BAQ_Services_Bancaires': 2,
#  'Bilan_suivi_relationnel': 3,
#  'Credit_agri_pro': 4,
#  'Credit_conso': 5,
#  'Credit_habitat': 6,
#  'Credit_travaux': 7,
#  'Credit_vehicule': 8,
#  'Entree_en_relation_Conquetes': 9,
#  'Epargne_disponible': 10,
#  'Epargne_terme': 11,
#  'Evenements_de_vie': 12,
#  'Non_specifie_Credit_Assurance_Epargne_': 13,
#  'Point_d_attention_risques': 14,
#  'Projet_exceptionnel_': 15,
#  'Reclamation_Insatisfaction_client': 16}

# %%
df['label'] = df.category.replace(label_dict)

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(df.index.values, 
                                                  df.label.values, 
                                                  test_size=0.15, 
                                                  random_state=42, 
                                                  stratify=df.label.values)

df['text'] = ['not_set']*df.shape[0]

df.loc[X_train, 'data_type'] = 'train'
df.loc[X_val, 'data_type'] = 'val'

df.groupby(['category', 'label', 'data_type']).count()
# Out:
#                                                         text  content  \
# category                               label data_type
# Assurance_de_Biens                     0     train       344      344
#                                              val          61       61
# Assurance_de_Personnes                 1     train       325      325
#                                              val          57       57
# BAQ_Services_Bancaires                 2     train       346      346
#                                              val          61       61
# Bilan_suivi_relationnel                3     train       286      286
#                                              val          51       51
# Credit_agri_pro                        4     train        58       58
#                                              val          10       10
# Credit_conso                           5     train       117      117
#                                              val          21       21
# Credit_habitat                         6     train       341      341
#                                              val          60       60
# Credit_travaux                         7     train        45       45
#                                              val           8        8
# Credit_vehicule                        8     train        81       81
#                                              val          14       14
# Entree_en_relation_Conquetes           9     train       425      425
#                                              val          75       75
# Epargne_disponible                     10    train       301      301
#                                              val          53       53
# Epargne_terme                          11    train       642      642
#                                              val         114      114
# Evenements_de_vie                      12    train       139      139
#                                              val          25       25
# Non_specifie_Credit_Assurance_Epargne_ 13    train       302      302
#                                              val          53       53
# Point_d_attention_risques              14    train       500      500
#                                              val          88       88
# Projet_exceptionnel_                   15    train        97       97
#                                              val          17       17
# Reclamation_Insatisfaction_client      16    train       126      126
#                                              val          22       22
#
#                                                         category_id
# category                               label data_type
# Assurance_de_Biens                     0     train              344
#                                              val                 61
# Assurance_de_Personnes                 1     train              325
#                                              val                 57
# BAQ_Services_Bancaires                 2     train              346
#                                              val                 61
# Bilan_suivi_relationnel                3     train              286
#                                              val                 51
# Credit_agri_pro                        4     train               58
#                                              val                 10
# Credit_conso                           5     train              117
#                                              val                 21
# Credit_habitat                         6     train              341
#                                              val                 60
# Credit_travaux                         7     train               45
#                                              val                  8
# Credit_vehicule                        8     train               81
#                                              val                 14
# Entree_en_relation_Conquetes           9     train              425
#                                              val                 75
# Epargne_disponible                     10    train              301
#                                              val                 53
# Epargne_terme                          11    train              642
#                                              val                114
# Evenements_de_vie                      12    train              139
#                                              val                 25
# Non_specifie_Credit_Assurance_Epargne_ 13    train              302
#                                              val                 53
# Point_d_attention_risques              14    train              500
#                                              val                 88
# Projet_exceptionnel_                   15    train               97
#                                              val                 17
# Reclamation_Insatisfaction_client      16    train              126
#                                              val                 22

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', 
                                          do_lower_case=True)
                                          
encoded_data_train = tokenizer.batch_encode_plus(
    df[df.data_type=='train'].text.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)

encoded_data_val = tokenizer.batch_encode_plus(
    df[df.data_type=='val'].text.values, 
    add_special_tokens=True, 
    return_attention_mask=True, 
    pad_to_max_length=True, 
    max_length=256, 
    return_tensors='pt'
)


input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(df[df.data_type=='train'].label.values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
labels_val = torch.tensor(df[df.data_type=='val'].label.values)

dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_val = TensorDataset(input_ids_val, attention_masks_val, labels_val)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=433.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=440473133.0), HTML(value='')))
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

batch_size = 3

dataloader_train = DataLoader(dataset_train, 
                              sampler=RandomSampler(dataset_train), 
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_val, 
                                   sampler=SequentialSampler(dataset_val), 
                                   batch_size=batch_size)

# %%
from transformers import AdamW, get_linear_schedule_with_warmup

optimizer = AdamW(model.parameters(),
                  lr=1e-5, 
                  eps=1e-8)
                  
epochs = 2

scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps=0,
                                            num_training_steps=len(dataloader_train)*epochs)

# %%
from sklearn.metrics import f1_score

def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in label_dict.items()}
    
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

# %%
import random

seed_val = 17
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

print(device)
# Out:
# cpu

# %%
def evaluate(dataloader_val):

    model.eval()
    
    loss_val_total = 0
    predictions, true_vals = [], []
    
    for batch in dataloader_val:
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals
    
for epoch in tqdm(range(1, epochs+1)):
    
    model.train()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }       

        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
         
        
    torch.save(model.state_dict(), f'data_volume/finetuned_BERT_epoch_{epoch}.model')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    
    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    val_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {val_loss}')
    tqdm.write(f'F1 Score (Weighted): {val_f1}')

# %%
for epoch in tqdm(range(1, epochs+1)):
    
    model.t
    rain()
    
    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()
        
        batch = tuple(b.to(device) for b in batch)
        
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }       

        outputs = model(**inputs)
        
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()
        
        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
         
        
    torch.save(model.state_dict(), f'data_volume/finetuned_BERT_epoch_{epoch}.model')
        
    tqdm.write(f'\nEpoch {epoch}')
    
    loss_train_avg = loss_train_total/len(dataloader_train)            
    tqdm.write(f'Training loss: {loss_train_avg}')
    
    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    val_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {val_loss}')
    tqdm.write(f'F1 Score (Weighted): {val_f1}')

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)

model.to(device)

# %%
model.load_state_dict(torch.load('data_volume/finetuned_BERT_epoch_1.model', map_location=torch.device('cpu')))

# %%
_, predictions, true_vals = evaluate(dataloader_validation)

# %%
accuracy_per_class(predictions, true_vals)

# %% [markdown]
# # TEST NAIVE BAYES MULTINOMIAL

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer

nb = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB()),
              ])
nb.fit(X_train, y_train)

# %%time
from sklearn.metrics import classification_report
y_pred = nb.predict(X_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred,target_names=category_id))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-041e10ff9013> in <module>
#       7                ('clf', MultinomialNB()),
#       8               ])
# ----> 9 nb.fit(X_train, y_train)
#      10
#      11 get_ipython().run_line_magic('%time', '')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     328         """
#     329         fit_params_steps = self._check_fit_params(**fit_params)
# --> 330         Xt = self._fit(X, y, **fit_params_steps)
#     331         with _print_elapsed_time('Pipeline',
#     332                                  self._log_message(len(self.steps) - 1)):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params_steps)
#     290                 cloned_transformer = clone(transformer)
#     291             # Fit or load from cache the current transformer
# --> 292             X, fitted_transformer = fit_transform_one_cached(
#     293                 cloned_transformer, X, y, None,
#     294                 message_clsname='Pipeline',
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     350
#     351     def __call__(self, *args, **kwargs):
# --> 352         return self.func(*args, **kwargs)
#     353
#     354     def call_and_shelve(self, *args, **kwargs):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     738     with _print_elapsed_time(message_clsname, message):
#     739         if hasattr(transformer, 'fit_transform'):
# --> 740             res = transformer.fit_transform(X, y, **fit_params)
#     741         else:
#     742             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1196         max_features = self.max_features
#    1197
# -> 1198         vocabulary, X = self._count_vocab(raw_documents,
#    1199                                           self.fixed_vocabulary_)
#    1200
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1108         for doc in raw_documents:
#    1109             feature_counter = {}
# -> 1110             for feature in analyze(doc):
#    1111                 try:
#    1112                     feature_idx = vocabulary[feature]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     102     else:
#     103         if preprocessor is not None:
# --> 104             doc = preprocessor(doc)
#     105         if tokenizer is not None:
#     106             doc = tokenizer(doc)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in _preprocess(doc, accent_function, lower)
#      67     """
#      68     if lower:
# ---> 69         doc = doc.lower()
#      70     if accent_function is not None:
#      71         doc = accent_function(doc)
#
# AttributeError: 'numpy.int64' object has no attribute 'lower'

# %% [markdown]
# # TEST LSVM

# %%
from sklearn.linear_model import SGDClassifier

sgd = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42, max_iter=5, tol=None)),
               ])
sgd.fit(X_train, y_train)

# %%time

y_pred = sgd.predict(X_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred,target_names=my_tags))

# %% [markdown]
# # TEST LOG REG

# %%
from sklearn.linear_model import LogisticRegression

logreg = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', LogisticRegression(n_jobs=1, C=1e5)),
               ])
logreg.fit(X_train, y_train)

# %%time

y_pred = logreg.predict(X_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred,target_names=my_tags))
